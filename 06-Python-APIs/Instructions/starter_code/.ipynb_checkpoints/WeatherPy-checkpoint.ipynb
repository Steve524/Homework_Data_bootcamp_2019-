# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# '8d0393fe52561201e795ba053d67bc09'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

queryurl = f'{url}appid={api_key}&units={units}&q='

print(queryurl)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=

# %%
city_name = []
cloudiness = []
max_temp = []
wind_speed= []
humidity = []
country = []
date = []
lat = []
lng = []



print("Begining Data Retrieval")
print("------------------------")

record = 0

for city in cities: 
    try:
        record +=1
        
        print(f"Processing record {record} | {city}")
        print(f'{queryurl}{city}')
          
        response = requests.get(queryurl + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        humidity.append(response["main"]["humidity"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
            
    except:
        print("City not found. skipping...")
    continue
# Out:
# Begining Data Retrieval
# ------------------------
# Processing record 1 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=naze
# Processing record 2 | yumen
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yumen
# Processing record 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=provideniya
# Processing record 4 | kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kaeo
# Processing record 5 | inirida
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=inirida
# Processing record 6 | lebowakgomo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lebowakgomo
# Processing record 7 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ushuaia
# Processing record 8 | jaumave
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jaumave
# Processing record 9 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=samusu
# City not found. skipping...
# Processing record 10 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=taolanaro
# City not found. skipping...
# Processing record 11 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hermanus
# Processing record 12 | san matias
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san matias
# Processing record 13 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=new norfolk
# Processing record 14 | natal
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=natal
# Processing record 15 | mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mokhsogollokh
# Processing record 16 | monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=monrovia
# Processing record 17 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dikson
# Processing record 18 | santa cruz de la palma
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=santa cruz de la palma
# Processing record 19 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=busselton
# Processing record 20 | nassau
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nassau
# Processing record 21 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint-philippe
# Processing record 22 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kapaa
# Processing record 23 | pakxe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pakxe
# Processing record 24 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=guerrero negro
# Processing record 25 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=omboue
# Processing record 26 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rikitea
# Processing record 27 | hay river
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hay river
# Processing record 28 | teguldet
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=teguldet
# Processing record 29 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bredasdorp
# Processing record 30 | asau
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=asau
# Processing record 31 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saskylakh
# Processing record 32 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=illoqqortoormiut
# City not found. skipping...
# Processing record 33 | santa catarina de tepehuanes
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=santa catarina de tepehuanes
# Processing record 34 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tura
# Processing record 35 | ust-karsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ust-karsk
# Processing record 36 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=xai-xai
# Processing record 37 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=puerto ayora
# Processing record 38 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mar del plata
# Processing record 39 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=qaanaaq
# Processing record 40 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hobart
# Processing record 41 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tasiilaq
# Processing record 42 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=punta arenas
# Processing record 43 | grand centre
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grand centre
# City not found. skipping...
# Processing record 44 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port alfred
# Processing record 45 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hilo
# Processing record 46 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=esperance
# Processing record 47 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vaini
# Processing record 48 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=albany
# Processing record 49 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mehamn
# Processing record 50 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=salalah
# Processing record 51 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=komsomolskiy
# Processing record 52 | padang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=padang
# Processing record 53 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=khatanga
# Processing record 54 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kruisfontein
# Processing record 55 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bathsheba
# Processing record 56 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=fort nelson
# Processing record 57 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bilibino
# Processing record 58 | grants
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grants
# Processing record 59 | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bereda
# Processing record 60 | warqla
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=warqla
# City not found. skipping...
# Processing record 61 | tucumcari
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tucumcari
# Processing record 62 | tabuk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tabuk
# Processing record 63 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zhigansk
# Processing record 64 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zyryanka
# Processing record 65 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aklavik
# Processing record 66 | rundu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rundu
# Processing record 67 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=thompson
# Processing record 68 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mataura
# Processing record 69 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nikolskoye
# Processing record 70 | sorbhog
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sorbhog
# Processing record 71 | ha noi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ha noi
# Processing record 72 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=faanui
# Processing record 73 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chokurdakh
# Processing record 74 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=barentsburg
# City not found. skipping...
# Processing record 75 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cayenne
# Processing record 76 | weston
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=weston
# Processing record 77 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bonavista
# Processing record 78 | kollam
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kollam
# Processing record 79 | andenes
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=andenes
# Processing record 80 | aljezur
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aljezur
# Processing record 81 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ust-tsilma
# Processing record 82 | zakopane
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zakopane
# Processing record 83 | muroto
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=muroto
# Processing record 84 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=acapulco
# Processing record 85 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cape town
# Processing record 86 | baglung
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=baglung
# Processing record 87 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ekhabi
# Processing record 88 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=leningradskiy
# Processing record 89 | chumphon
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chumphon
# Processing record 90 | ca mau
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ca mau
# Processing record 91 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=okhotsk
# Processing record 92 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mount gambier
# Processing record 93 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=klaksvik
# Processing record 94 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=avarua
# Processing record 95 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=la asuncion
# Processing record 96 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ancud
# Processing record 97 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dolbeau
# City not found. skipping...
# Processing record 98 | guiglo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=guiglo
# Processing record 99 | stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=stykkisholmur
# Processing record 100 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=victoria
# Processing record 101 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tsihombe
# City not found. skipping...
# Processing record 102 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mys shmidta
# City not found. skipping...
# Processing record 103 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=butaritari
# Processing record 104 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ribeira grande
# Processing record 105 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tuktoyaktuk
# Processing record 106 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=katsuura
# Processing record 107 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kavieng
# Processing record 108 | rungata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rungata
# City not found. skipping...
# Processing record 109 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ponta do sol
# Processing record 110 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cap malheureux
# Processing record 111 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=arraial do cabo
# Processing record 112 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kavaratti
# Processing record 113 | nivala
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nivala
# Processing record 114 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=buraydah
# Processing record 115 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nizhneyansk
# City not found. skipping...
# Processing record 116 | minab
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=minab
# Processing record 117 | high level
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=high level
# Processing record 118 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=avera
# Processing record 119 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rio grande
# Processing record 120 | jackson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jackson
# Processing record 121 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=coquimbo
# Processing record 122 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mandalgovi
# Processing record 123 | nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nantucket
# Processing record 124 | ginir
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ginir
# Processing record 125 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=amderma
# City not found. skipping...
# Processing record 126 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bethel
# Processing record 127 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jamestown
# Processing record 128 | delta del tigre
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=delta del tigre
# Processing record 129 | port huron
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port huron
# Processing record 130 | yuanping
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yuanping
# Processing record 131 | ural
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ural
# Processing record 132 | tubruq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tubruq
# City not found. skipping...
# Processing record 133 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vaitupu
# City not found. skipping...
# Processing record 134 | luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=luwuk
# Processing record 135 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=souillac
# Processing record 136 | saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saleaula
# City not found. skipping...
# Processing record 137 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bur gabo
# City not found. skipping...
# Processing record 138 | malakisi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=malakisi
# City not found. skipping...
# Processing record 139 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kaitangata
# Processing record 140 | dalby
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dalby
# Processing record 141 | miri
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=miri
# Processing record 142 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=naryan-mar
# Processing record 143 | ternate
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ternate
# Processing record 144 | taraz
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=taraz
# Processing record 145 | deniliquin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=deniliquin
# Processing record 146 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=atuona
# Processing record 147 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=caravelas
# Processing record 148 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sao filipe
# Processing record 149 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tiksi
# Processing record 150 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bluff
# Processing record 151 | ronne
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ronne
# Processing record 152 | mutis
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mutis
# Processing record 153 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hami
# Processing record 154 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=puerto carreno
# Processing record 155 | plouzane
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=plouzane
# Processing record 156 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grand river south east
# City not found. skipping...
# Processing record 157 | naantali
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=naantali
# Processing record 158 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nome
# Processing record 159 | moron
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=moron
# Processing record 160 | turayf
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=turayf
# Processing record 161 | vallenar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vallenar
# Processing record 162 | suez
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=suez
# Processing record 163 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=skjervoy
# Processing record 164 | sao desiderio
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sao desiderio
# Processing record 165 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=iqaluit
# Processing record 166 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port elizabeth
# Processing record 167 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kodiak
# Processing record 168 | kadi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kadi
# Processing record 169 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=laguna
# Processing record 170 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=alofi
# Processing record 171 | marzuq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=marzuq
# Processing record 172 | dodge city
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dodge city
# Processing record 173 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pevek
# Processing record 174 | khandbari
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=khandbari
# Processing record 175 | santa luzia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=santa luzia
# Processing record 176 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rawson
# Processing record 177 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sao joao da barra
# Processing record 178 | russell
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=russell
# Processing record 179 | quedlinburg
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=quedlinburg
# Processing record 180 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lakatoro
# Processing record 181 | zhob
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zhob
# Processing record 182 | manbij
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=manbij
# Processing record 183 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=margate
# Processing record 184 | north bend
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=north bend
# Processing record 185 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lebu
# Processing record 186 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ixtapa
# Processing record 187 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sentyabrskiy
# City not found. skipping...
# Processing record 188 | nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nishihara
# Processing record 189 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jiuquan
# Processing record 190 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yellowknife
# Processing record 191 | uwayl
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=uwayl
# City not found. skipping...
# Processing record 192 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cockburn town
# Processing record 193 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lata
# Processing record 194 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=maniitsoq
# Processing record 195 | gamba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=gamba
# Processing record 196 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dingle
# Processing record 197 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cherskiy
# Processing record 198 | viedma
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=viedma
# Processing record 199 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tabiauea
# City not found. skipping...
# Processing record 200 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=barrow
# Processing record 201 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint george
# Processing record 202 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=attawapiskat
# City not found. skipping...
# Processing record 203 | rajanpur
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rajanpur
# Processing record 204 | ondorhaan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ondorhaan
# City not found. skipping...
# Processing record 205 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=namatanai
# Processing record 206 | ferkessedougou
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ferkessedougou
# Processing record 207 | storozhevaya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=storozhevaya
# Processing record 208 | kenai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kenai
# Processing record 209 | lukovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lukovetskiy
# Processing record 210 | yazoo city
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yazoo city
# Processing record 211 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=severo-kurilsk
# Processing record 212 | eldorado
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=eldorado
# Processing record 213 | mina
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mina
# Processing record 214 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kirakira
# Processing record 215 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tumannyy
# City not found. skipping...
# Processing record 216 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kloulklubed
# Processing record 217 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hithadhoo
# Processing record 218 | myjava
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=myjava
# Processing record 219 | harper
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=harper
# Processing record 220 | stoyba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=stoyba
# City not found. skipping...
# Processing record 221 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cabedelo
# Processing record 222 | bolshaya martynovka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bolshaya martynovka
# Processing record 223 | wajima
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=wajima
# Processing record 224 | meyzieu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=meyzieu
# Processing record 225 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=longyearbyen
# Processing record 226 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=alice springs
# Processing record 227 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cabo san lucas
# Processing record 228 | paradwip
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=paradwip
# City not found. skipping...
# Processing record 229 | okha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=okha
# Processing record 230 | bukama
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bukama
# Processing record 231 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dunedin
# Processing record 232 | malysheva
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=malysheva
# Processing record 233 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rocha
# Processing record 234 | zhigalovo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zhigalovo
# Processing record 235 | jatiroto
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jatiroto
# Processing record 236 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bengkulu
# Processing record 237 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grindavik
# Processing record 238 | khorramshahr
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=khorramshahr
# Processing record 239 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=la ronge
# Processing record 240 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=palabuhanratu
# City not found. skipping...
# Processing record 241 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=codrington
# Processing record 242 | kampong thum
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kampong thum
# Processing record 243 | shitanjing
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=shitanjing
# Processing record 244 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ostrovnoy
# Processing record 245 | senneterre
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=senneterre
# Processing record 246 | tigil
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tigil
# Processing record 247 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nanortalik
# Processing record 248 | iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=iskateley
# Processing record 249 | beira
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=beira
# Processing record 250 | xining
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=xining
# Processing record 251 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ucluelet
# Processing record 252 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=georgetown
# Processing record 253 | nehe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nehe
# Processing record 254 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint-georges
# Processing record 255 | phnum penh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=phnum penh
# City not found. skipping...
# Processing record 256 | trelew
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=trelew
# Processing record 257 | buchanan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=buchanan
# Processing record 258 | gao
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=gao
# Processing record 259 | ohey
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ohey
# Processing record 260 | fukue
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=fukue
# Processing record 261 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=itarema
# Processing record 262 | inverell
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=inverell
# Processing record 263 | soyo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=soyo
# Processing record 264 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=touros
# Processing record 265 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kahului
# Processing record 266 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chuy
# Processing record 267 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sobolevo
# Processing record 268 | le mars
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=le mars
# Processing record 269 | coari
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=coari
# Processing record 270 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=alta floresta
# Processing record 271 | puro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=puro
# Processing record 272 | urusha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=urusha
# Processing record 273 | vila
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vila
# Processing record 274 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=upernavik
# Processing record 275 | poyarkovo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=poyarkovo
# Processing record 276 | kourou
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kourou
# Processing record 277 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=airai
# Processing record 278 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bambous virieux
# Processing record 279 | tigwi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tigwi
# City not found. skipping...
# Processing record 280 | khorixas
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=khorixas
# Processing record 281 | igarka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=igarka
# Processing record 282 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kununurra
# Processing record 283 | vagur
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vagur
# Processing record 284 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=camacha
# Processing record 285 | varzea grande
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=varzea grande
# Processing record 286 | daru
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=daru
# Processing record 287 | vostok
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vostok
# Processing record 288 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=belushya guba
# City not found. skipping...
# Processing record 289 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=champerico
# Processing record 290 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=luderitz
# Processing record 291 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mount isa
# Processing record 292 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=broome
# Processing record 293 | sumenep
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sumenep
# Processing record 294 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=puerto narino
# Processing record 295 | toamasina
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=toamasina
# Processing record 296 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=carnarvon
# Processing record 297 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pisco
# Processing record 298 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aksu
# Processing record 299 | floro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=floro
# Processing record 300 | sagua la grande
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sagua la grande
# Processing record 301 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cidreira
# Processing record 302 | pinyug
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pinyug
# Processing record 303 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yulara
# Processing record 304 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=castro
# Processing record 305 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=turukhansk
# Processing record 306 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=clyde river
# Processing record 307 | aloleng
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aloleng
# Processing record 308 | felidhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=felidhoo
# City not found. skipping...
# Processing record 309 | usakos
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=usakos
# Processing record 310 | sakakah
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sakakah
# Processing record 311 | colares
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=colares
# Processing record 312 | coos bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=coos bay
# Processing record 313 | nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nyurba
# Processing record 314 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vardo
# Processing record 315 | tortoli
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tortoli
# Processing record 316 | japura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=japura
# Processing record 317 | pangody
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pangody
# Processing record 318 | san rafael
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san rafael
# Processing record 319 | bandar-e lengeh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bandar-e lengeh
# Processing record 320 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=egvekinot
# Processing record 321 | brownsville
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=brownsville
# Processing record 322 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=isangel
# Processing record 323 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hamilton
# Processing record 324 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port-cartier
# Processing record 325 | lorengau
# ...
# Processing record 512 | minbu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=minbu
# Processing record 513 | santiago del estero
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=santiago del estero
# Processing record 514 | salta
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=salta
# Processing record 515 | malumfashi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=malumfashi
# Processing record 516 | hecun
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hecun
# Processing record 517 | ardistan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ardistan
# City not found. skipping...
# Processing record 518 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lasa
# Processing record 519 | moissala
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=moissala
# Processing record 520 | sao lourenco da serra
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sao lourenco da serra
# Processing record 521 | vaitape
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vaitape
# Processing record 522 | fort morgan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=fort morgan
# Processing record 523 | ambon
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ambon
# Processing record 524 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jacareacanga
# Processing record 525 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ust-maya
# Processing record 526 | lixourion
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lixourion
# Processing record 527 | lubao
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lubao
# Processing record 528 | tsumeb
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tsumeb
# Processing record 529 | tsabong
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tsabong
# Processing record 530 | vitre
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vitre
# Processing record 531 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=makakilo city
# Processing record 532 | kemin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kemin
# Processing record 533 | kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kamenka
# Processing record 534 | brae
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=brae
# Processing record 535 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hasaki
# Processing record 536 | lokachi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lokachi
# Processing record 537 | praia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=praia
# Processing record 538 | kibala
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kibala
# Processing record 539 | bolshaya chernigovka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bolshaya chernigovka
# City not found. skipping...
# Processing record 540 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=teahupoo
# Processing record 541 | kijang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kijang
# Processing record 542 | tunduru
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tunduru
# City not found. skipping...
# Processing record 543 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=derzhavinsk
# Processing record 544 | havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=havoysund
# Processing record 545 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vila franca do campo
# Processing record 546 | viligili
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=viligili
# City not found. skipping...
# Processing record 547 | arman
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=arman
# Processing record 548 | zeya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zeya
# Processing record 549 | kaka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kaka
# Processing record 550 | linjiang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=linjiang
# Processing record 551 | swan hill
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=swan hill
# Processing record 552 | san pedro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san pedro
# Processing record 553 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=paamiut
# Processing record 554 | esil
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=esil
# Processing record 555 | gombong
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=gombong
# Processing record 556 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sitka
# Processing record 557 | leonidovo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=leonidovo
# Processing record 558 | burgeo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=burgeo
# Processing record 559 | xam nua
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=xam nua
# Processing record 560 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chapais
# Processing record 561 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tasbuget
# City not found. skipping...
# Processing record 562 | bereznik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bereznik
# Processing record 563 | reitz
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=reitz
# Processing record 564 | parkes
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=parkes
# Processing record 565 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=coihaique
# Processing record 566 | tutoia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tutoia
# Processing record 567 | worland
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=worland
# Processing record 568 | tezu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tezu
# Processing record 569 | atbasar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=atbasar
# Processing record 570 | encruzilhada do sul
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=encruzilhada do sul
# Processing record 571 | vila do maio
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vila do maio
# Processing record 572 | kyren
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kyren
# Processing record 573 | iralaya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=iralaya
# Processing record 574 | gravdal
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=gravdal
# Processing record 575 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tuatapere
# Processing record 576 | elliot lake
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=elliot lake
# Processing record 577 | carazinho
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=carazinho
# Processing record 578 | zyryanovsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zyryanovsk
# Processing record 579 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=buala
# Processing record 580 | nikki
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nikki
# Processing record 581 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=necochea
# Processing record 582 | ugep
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ugep
# Processing record 583 | piritiba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=piritiba
# Processing record 584 | faro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=faro
# Processing record 585 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=oktyabrskoye
# Processing record 586 | grootegast
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grootegast
# Processing record 587 | altus
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=altus
# Processing record 588 | medea
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=medea
# Processing record 589 | maltahohe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=maltahohe
# Processing record 590 | college
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=college
# Processing record 591 | volchansk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=volchansk
# Processing record 592 | inongo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=inongo
# Processing record 593 | kang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kang
# Processing record 594 | hanyang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hanyang
# Processing record 595 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vila velha
# Processing record 596 | bhag
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bhag
# Processing record 597 | mayumba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mayumba
# Processing record 598 | mokokchung
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mokokchung
# Processing record 599 | merritt island
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=merritt island
# Processing record 600 | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tiznit
# Processing record 601 | santa eulalia del rio
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=santa eulalia del rio
# City not found. skipping...
# Processing record 602 | aras
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aras
# Processing record 603 | morondava
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=morondava
# Processing record 604 | okulovka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=okulovka
# Processing record 605 | jinxiang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jinxiang
# Processing record 606 | orocue
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=orocue
# Processing record 607 | dondo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dondo
# Processing record 608 | morrope
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=morrope
# Processing record 609 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ponta delgada
# Processing record 610 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mayo
# Processing record 611 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ahipara
# Processing record 612 | chagda
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chagda
# City not found. skipping...
# Processing record 613 | port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port moresby
# Processing record 614 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kulhudhuffushi
# Processing record 615 | garmsar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=garmsar
# Processing record 616 | bhiwandi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bhiwandi
# Processing record 617 | chebenki
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chebenki
# Processing record 618 | odessa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=odessa
# Processing record 619 | wanaka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=wanaka
# Processing record 620 | hirara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hirara

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df=pd.DataFrame({
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Lat": lat,
    "Lng": lng,
    "Humidity": humidity,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
    })

df.to_csv(r'weather_data.csv', index = False)

# %%
weather_df = pd.read_csv('weather_data.csv')
weather_df.head()
# Out:
#           City  Cloudiness Country        Date    Lat     Lng  Humidity  \
# 0         Naze          75      JP  1583617034  28.37  129.48        88
# 1        Yumen         100      CN  1583617034  40.28   97.20        52
# 2  Provideniya           0      RU  1583616986  64.38 -173.30        91
# 3         Kaeo          58      NZ  1583617034 -35.10  173.78        80
# 4      Inírida          19      CO  1583617034   3.87  -67.92        57
#
#    Max Temp  Wind Speed
# 0     66.20       17.22
# 1     29.93        5.14
# 2      0.54        4.45
# 3     72.00        5.99
# 4     90.03        3.87

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
