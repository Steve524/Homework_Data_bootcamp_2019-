# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

queryurl = f'{url}appid={api_key}&units={units}&q='

print(queryurl)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=

# %%
city_name = []
cloudiness = []
max_temp = []
wind_speed= []
humidity = []
country = []
date = []
lat = []
lng = []



print("Begining Data Retrieval")
print("------------------------")

record = 0

for city in cities: 
    try:
        record +=1
        
        print(f"Processing record {record} | {city}")
        print(f'{queryurl}{city}')
          
        response = requests.get(queryurl + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        humidity.append(response["main"]["humidity"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
            
    except:
        print("City not found. skipping...")
    continue
# Out:
# Begining Data Retrieval
# ------------------------
# Processing record 1 | denpasar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=denpasar
# Processing record 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=busselton
# Processing record 3 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mataura
# Processing record 4 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vardo
# Processing record 5 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=namatanai
# Processing record 6 | yangmei
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yangmei
# Processing record 7 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=barrow
# Processing record 8 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jamestown
# Processing record 9 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=upernavik
# Processing record 10 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tsihombe
# City not found. skipping...
# Processing record 11 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rikitea
# Processing record 12 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ushuaia
# Processing record 13 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=east london
# Processing record 14 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kudahuvadhoo
# Processing record 15 | teya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=teya
# Processing record 16 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mys shmidta
# City not found. skipping...
# Processing record 17 | sao borja
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sao borja
# Processing record 18 | limbang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=limbang
# Processing record 19 | priamurskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=priamurskiy
# Processing record 20 | xghajra
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=xghajra
# City not found. skipping...
# Processing record 21 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dikson
# Processing record 22 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hovd
# Processing record 23 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=beloha
# Processing record 24 | camana
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=camana
# Processing record 25 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bluff
# Processing record 26 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hithadhoo
# Processing record 27 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=coquimbo
# Processing record 28 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rocha
# Processing record 29 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tuktoyaktuk
# Processing record 30 | pa sang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pa sang
# Processing record 31 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port lincoln
# Processing record 32 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jalu
# Processing record 33 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=belushya guba
# City not found. skipping...
# Processing record 34 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=portland
# Processing record 35 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cape town
# Processing record 36 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=butaritari
# Processing record 37 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=torbay
# Processing record 38 | geresk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=geresk
# City not found. skipping...
# Processing record 39 | aloleng
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aloleng
# Processing record 40 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ngukurr
# City not found. skipping...
# Processing record 41 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=clyde river
# Processing record 42 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bambous virieux
# Processing record 43 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=punta arenas
# Processing record 44 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port alfred
# Processing record 45 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=komsomolskiy
# Processing record 46 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cockburn town
# Processing record 47 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=avarua
# Processing record 48 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=khatanga
# Processing record 49 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=taolanaro
# City not found. skipping...
# Processing record 50 | xining
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=xining
# Processing record 51 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mount isa
# Processing record 52 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=albany
# Processing record 53 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kapaa
# Processing record 54 | pangai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pangai
# Processing record 55 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mount gambier
# Processing record 56 | aybak
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aybak
# City not found. skipping...
# Processing record 57 | camapua
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=camapua
# Processing record 58 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yellowknife
# Processing record 59 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=oranjemund
# Processing record 60 | stavrovo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=stavrovo
# Processing record 61 | ulan-ude
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ulan-ude
# Processing record 62 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=borogontsy
# Processing record 63 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nikolskoye
# Processing record 64 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nizhniy kuranakh
# Processing record 65 | aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aykhal
# Processing record 66 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=carnarvon
# Processing record 67 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=faanui
# Processing record 68 | hay river
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hay river
# Processing record 69 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cidreira
# Processing record 70 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sept-iles
# Processing record 71 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hermanus
# Processing record 72 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bethel
# Processing record 73 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tasiilaq
# Processing record 74 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kropotkin
# Processing record 75 | kisaran
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kisaran
# Processing record 76 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint-philippe
# Processing record 77 | kristiansund
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kristiansund
# Processing record 78 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=richards bay
# Processing record 79 | lagos
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lagos
# Processing record 80 | sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sistranda
# Processing record 81 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint anthony
# Processing record 82 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chokurdakh
# Processing record 83 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kodiak
# Processing record 84 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cabo san lucas
# Processing record 85 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=korla
# Processing record 86 | tottori
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tottori
# Processing record 87 | meyungs
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=meyungs
# City not found. skipping...
# Processing record 88 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=illoqqortoormiut
# City not found. skipping...
# Processing record 89 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=severo-kurilsk
# Processing record 90 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint george
# Processing record 91 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=shenjiamen
# Processing record 92 | horsham
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=horsham
# Processing record 93 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hobart
# Processing record 94 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yulara
# Processing record 95 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=new norfolk
# Processing record 96 | brasileia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=brasileia
# Processing record 97 | san roque
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san roque
# Processing record 98 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lebu
# Processing record 99 | akhmim
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=akhmim
# Processing record 100 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mar del plata
# Processing record 101 | xapuri
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=xapuri
# Processing record 102 | sao sebastiao
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sao sebastiao
# Processing record 103 | joetsu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=joetsu
# Processing record 104 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vaini
# Processing record 105 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ust-kamchatsk
# City not found. skipping...
# Processing record 106 | taitung
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=taitung
# Processing record 107 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sao filipe
# Processing record 108 | xichang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=xichang
# Processing record 109 | mocajuba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mocajuba
# Processing record 110 | isernia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=isernia
# Processing record 111 | ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ondjiva
# Processing record 112 | athabasca
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=athabasca
# Processing record 113 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ilulissat
# Processing record 114 | mao
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mao
# Processing record 115 | taltal
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=taltal
# Processing record 116 | williams lake
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=williams lake
# Processing record 117 | mildura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mildura
# Processing record 118 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ixtapa
# Processing record 119 | aktyubinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aktyubinskiy
# Processing record 120 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tuatapere
# Processing record 121 | khash
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=khash
# Processing record 122 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=arraial do cabo
# Processing record 123 | eureka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=eureka
# Processing record 124 | mangrol
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mangrol
# Processing record 125 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=samusu
# City not found. skipping...
# Processing record 126 | rudbar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rudbar
# Processing record 127 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nizhneyansk
# City not found. skipping...
# Processing record 128 | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bereda
# Processing record 129 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vao
# Processing record 130 | ligayan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ligayan
# Processing record 131 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hilo
# Processing record 132 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sentyabrskiy
# City not found. skipping...
# Processing record 133 | dalvik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dalvik
# Processing record 134 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bredasdorp
# Processing record 135 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port elizabeth
# Processing record 136 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mahebourg
# Processing record 137 | sangar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sangar
# Processing record 138 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chuy
# Processing record 139 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vestmanna
# Processing record 140 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san patricio
# Processing record 141 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ugoofaaru
# Processing record 142 | progreso
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=progreso
# Processing record 143 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=barentsburg
# City not found. skipping...
# Processing record 144 | dodge city
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dodge city
# Processing record 145 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=castro
# Processing record 146 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bengkulu
# Processing record 147 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kalmunai
# Processing record 148 | cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cururupu
# Processing record 149 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vila velha
# Processing record 150 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=narsaq
# Processing record 151 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=thompson
# Processing record 152 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kavaratti
# Processing record 153 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pevek
# Processing record 154 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=amderma
# City not found. skipping...
# Processing record 155 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vaitupu
# City not found. skipping...
# Processing record 156 | zachagansk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zachagansk
# City not found. skipping...
# Processing record 157 | tampere
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tampere
# Processing record 158 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kununurra
# Processing record 159 | durban
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=durban
# Processing record 160 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bac lieu
# Processing record 161 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=angoche
# Processing record 162 | vaitape
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vaitape
# Processing record 163 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kaitangata
# Processing record 164 | chabahar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chabahar
# Processing record 165 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hasaki
# Processing record 166 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=atuona
# Processing record 167 | tame
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tame
# Processing record 168 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=puerto ayora
# Processing record 169 | gurgentepe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=gurgentepe
# Processing record 170 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tual
# Processing record 171 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=qaanaaq
# Processing record 172 | elena
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=elena
# Processing record 173 | payyannur
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=payyannur
# Processing record 174 | college
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=college
# Processing record 175 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ulladulla
# Processing record 176 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kavieng
# Processing record 177 | bryan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bryan
# Processing record 178 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=olafsvik
# Processing record 179 | mason city
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mason city
# Processing record 180 | veracruz
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=veracruz
# Processing record 181 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=santa rosa
# Processing record 182 | manyana
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=manyana
# Processing record 183 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=victoria
# Processing record 184 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=muros
# Processing record 185 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vila franca do campo
# Processing record 186 | roebourne
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=roebourne
# Processing record 187 | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tiznit
# Processing record 188 | balkanabat
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=balkanabat
# Processing record 189 | kisesa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kisesa
# Processing record 190 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=laguna
# Processing record 191 | juruti
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=juruti
# Processing record 192 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=fort nelson
# Processing record 193 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=provideniya
# Processing record 194 | wattegama
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=wattegama
# Processing record 195 | saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saleaula
# City not found. skipping...
# Processing record 196 | hailey
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hailey
# Processing record 197 | nazarovo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nazarovo
# Processing record 198 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=husavik
# Processing record 199 | rungata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rungata
# City not found. skipping...
# Processing record 200 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kruisfontein
# Processing record 201 | duitama
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=duitama
# Processing record 202 | coron
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=coron
# Processing record 203 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kloulklubed
# Processing record 204 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tiksi
# Processing record 205 | port augusta
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port augusta
# Processing record 206 | maceio
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=maceio
# Processing record 207 | brateiu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=brateiu
# Processing record 208 | pathein
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pathein
# Processing record 209 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=maniitsoq
# Processing record 210 | motala
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=motala
# Processing record 211 | dinsor
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dinsor
# City not found. skipping...
# Processing record 212 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=airai
# Processing record 213 | ca mau
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ca mau
# Processing record 214 | tralee
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tralee
# Processing record 215 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=attawapiskat
# City not found. skipping...
# Processing record 216 | huilong
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=huilong
# Processing record 217 | saravan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saravan
# Processing record 218 | tabialan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tabialan
# City not found. skipping...
# Processing record 219 | strathmore
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=strathmore
# Processing record 220 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=belaya gora
# Processing record 221 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=georgetown
# Processing record 222 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rio gallegos
# Processing record 223 | palora
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=palora
# Processing record 224 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=shimoda
# Processing record 225 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=souillac
# Processing record 226 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saldanha
# Processing record 227 | shache
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=shache
# Processing record 228 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vilhena
# Processing record 229 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=solnechnyy
# Processing record 230 | nara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nara
# Processing record 231 | porbandar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=porbandar
# Processing record 232 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grand gaube
# Processing record 233 | sawtell
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sawtell
# Processing record 234 | wana
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=wana
# Processing record 235 | tayshet
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tayshet
# Processing record 236 | roald
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=roald
# Processing record 237 | aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=aksarka
# Processing record 238 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pacific grove
# Processing record 239 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sitka
# Processing record 240 | khasan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=khasan
# Processing record 241 | jurmala
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jurmala
# Processing record 242 | baft
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=baft
# Processing record 243 | sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sumbe
# Processing record 244 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=svetlogorsk
# Processing record 245 | zdvinsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zdvinsk
# Processing record 246 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tautira
# Processing record 247 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=la ronge
# Processing record 248 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=half moon bay
# Processing record 249 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ilhabela
# Processing record 250 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ucluelet
# Processing record 251 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=katsuura
# Processing record 252 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saskylakh
# Processing record 253 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=labuhan
# Processing record 254 | yandyki
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yandyki
# Processing record 255 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=acapulco
# Processing record 256 | menongue
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=menongue
# Processing record 257 | sorvag
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sorvag
# City not found. skipping...
# Processing record 258 | itoman
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=itoman
# Processing record 259 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=constitucion
# Processing record 260 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lompoc
# Processing record 261 | pecos
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pecos
# Processing record 262 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=codrington
# Processing record 263 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=beringovskiy
# Processing record 264 | jalpan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jalpan
# Processing record 265 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=camacha
# Processing record 266 | sulangan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sulangan
# Processing record 267 | kushima
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kushima
# Processing record 268 | basoko
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=basoko
# Processing record 269 | doka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=doka
# Processing record 270 | lithakia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lithakia
# Processing record 271 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yar-sale
# Processing record 272 | anchorage
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=anchorage
# Processing record 273 | bristol
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bristol
# Processing record 274 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=broome
# Processing record 275 | ambulu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ambulu
# Processing record 276 | vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vanimo
# Processing record 277 | zeya
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=zeya
# Processing record 278 | borama
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=borama
# City not found. skipping...
# Processing record 279 | tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tessalit
# Processing record 280 | tanete
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tanete
# Processing record 281 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san cristobal
# Processing record 282 | vitim
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=vitim
# Processing record 283 | magnitka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=magnitka
# Processing record 284 | el alto
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=el alto
# Processing record 285 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=wahiawa
# Processing record 286 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nelson bay
# Processing record 287 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=salinopolis
# Processing record 288 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grand river south east
# City not found. skipping...
# Processing record 289 | angra
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=angra
# City not found. skipping...
# Processing record 290 | yanchukan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yanchukan
# City not found. skipping...
# Processing record 291 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kasongo-lunda
# Processing record 292 | talen
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=talen
# Processing record 293 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nouadhibou
# Processing record 294 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=atambua
# Processing record 295 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=longyearbyen
# Processing record 296 | la ciotat
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=la ciotat
# Processing record 297 | karatau
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=karatau
# Processing record 298 | okha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=okha
# Processing record 299 | honiara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=honiara
# Processing record 300 | ballina
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ballina
# Processing record 301 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=petropavlovsk-kamchatskiy
# Processing record 302 | marcona
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=marcona
# City not found. skipping...
# Processing record 303 | scarborough
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=scarborough
# Processing record 304 | adrar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=adrar
# Processing record 305 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ponta do sol
# Processing record 306 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=touros
# Processing record 307 | helena
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=helena
# Processing record 308 | anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=anadyr
# Processing record 309 | solovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=solovetskiy
# City not found. skipping...
# Processing record 310 | bereznik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bereznik
# Processing record 311 | afzalpur
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=afzalpur
# Processing record 312 | rambha
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rambha
# Processing record 313 | bocaranga
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bocaranga
# City not found. skipping...
# Processing record 314 | razole
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=razole
# Processing record 315 | boden
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=boden
# Processing record 316 | trinidad
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=trinidad
# Processing record 317 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=omsukchan
# Processing record 318 | paredon
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=paredon
# Processing record 319 | dabola
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dabola
# Processing record 320 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hami
# Processing record 321 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=esperance
# Processing record 322 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tumannyy
# City not found. skipping...
# Processing record 323 | brae
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=brae
# Processing record 324 | independencia
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=independencia
# Processing record 325 | moiyabana
# ...
# Processing record 500 | boali
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=boali
# Processing record 501 | ewo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ewo
# Processing record 502 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lufilufi
# Processing record 503 | kem
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kem
# Processing record 504 | dubbo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dubbo
# Processing record 505 | nagorsk
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nagorsk
# Processing record 506 | pozoblanco
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pozoblanco
# Processing record 507 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=skjervoy
# Processing record 508 | cairns
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cairns
# Processing record 509 | channel-port aux basques
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=channel-port aux basques
# Processing record 510 | teknaf
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=teknaf
# Processing record 511 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kungurtug
# Processing record 512 | austin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=austin
# Processing record 513 | spring hill
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=spring hill
# Processing record 514 | gladeview
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=gladeview
# Processing record 515 | kazerun
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kazerun
# Processing record 516 | yingkou
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yingkou
# Processing record 517 | jadu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=jadu
# Processing record 518 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint-georges
# Processing record 519 | baker city
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=baker city
# Processing record 520 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tilichiki
# Processing record 521 | sajokaza
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sajokaza
# Processing record 522 | tukrah
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tukrah
# Processing record 523 | partenit
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=partenit
# Processing record 524 | auki
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=auki
# Processing record 525 | chumikan
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=chumikan
# Processing record 526 | fukue
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=fukue
# Processing record 527 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bonavista
# Processing record 528 | kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kaeo
# Processing record 529 | teguldet
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=teguldet
# Processing record 530 | porto recanati
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=porto recanati
# Processing record 531 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mnogovershinnyy
# Processing record 532 | conakry
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=conakry
# Processing record 533 | sycamore
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sycamore
# Processing record 534 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=yeppoon
# Processing record 535 | smoky lake
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=smoky lake
# Processing record 536 | stornoway
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=stornoway
# Processing record 537 | makat
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=makat
# Processing record 538 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port shepstone
# Processing record 539 | araouane
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=araouane
# Processing record 540 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=leningradskiy
# Processing record 541 | staryy nadym
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=staryy nadym
# Processing record 542 | urumqi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=urumqi
# Processing record 543 | phrai bung
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=phrai bung
# City not found. skipping...
# Processing record 544 | pachelma
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pachelma
# Processing record 545 | pasighat
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=pasighat
# Processing record 546 | demba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=demba
# Processing record 547 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=norman wells
# Processing record 548 | flagstaff
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=flagstaff
# Processing record 549 | mamlyutka
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=mamlyutka
# Processing record 550 | kolondieba
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kolondieba
# Processing record 551 | ngong
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ngong
# Processing record 552 | ibra
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=ibra
# Processing record 553 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=christchurch
# Processing record 554 | sabang
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sabang
# Processing record 555 | kargil
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kargil
# Processing record 556 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san quintin
# Processing record 557 | sigli
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sigli
# Processing record 558 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bambanglipuro
# Processing record 559 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nhulunbuy
# Processing record 560 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kathmandu
# Processing record 561 | taree
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=taree
# Processing record 562 | matara
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=matara
# Processing record 563 | sambek
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sambek
# Processing record 564 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bubaque
# Processing record 565 | general pico
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=general pico
# Processing record 566 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=caravelas
# Processing record 567 | muhos
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=muhos
# Processing record 568 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sinnamary
# Processing record 569 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=sola
# Processing record 570 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=valparaiso
# Processing record 571 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=nanakuli
# Processing record 572 | guilin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=guilin
# Processing record 573 | robertsport
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=robertsport
# Processing record 574 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=saint-pierre
# Processing record 575 | san rafael
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=san rafael
# Processing record 576 | humaita
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=humaita
# Processing record 577 | eskasem
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=eskasem
# City not found. skipping...
# Processing record 578 | duz
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=duz
# City not found. skipping...
# Processing record 579 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=dingle
# Processing record 580 | el jicaro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=el jicaro
# Processing record 581 | cedral
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=cedral
# Processing record 582 | bagdarin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bagdarin
# Processing record 583 | karlshamn
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=karlshamn
# Processing record 584 | wagga wagga
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=wagga wagga
# Processing record 585 | tawkar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tawkar
# City not found. skipping...
# Processing record 586 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=alofi
# Processing record 587 | salta
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=salta
# Processing record 588 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=egvekinot
# Processing record 589 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=bilibino
# Processing record 590 | rincon
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rincon
# Processing record 591 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=port hawkesbury
# Processing record 592 | smiltene
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=smiltene
# Processing record 593 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=paamiut
# Processing record 594 | hamina
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=hamina
# Processing record 595 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=grindavik
# Processing record 596 | baykit
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=baykit
# Processing record 597 | muncar
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=muncar
# Processing record 598 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=raudeberg
# Processing record 599 | solaro
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=solaro
# Processing record 600 | kuching
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kuching
# Processing record 601 | michelstadt
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=michelstadt
# Processing record 602 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=tura
# Processing record 603 | burica
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=burica
# City not found. skipping...
# Processing record 604 | japura
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=japura
# Processing record 605 | rodino
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=rodino
# Processing record 606 | normandin
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=normandin
# Processing record 607 | kuche
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=kuche
# City not found. skipping...
# Processing record 608 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=8d0393fe52561201e795ba053d67bc09&units=imperial&q=lata

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df=pd.DataFrame({
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Lat": lat,
    "Lng": lng,
    "Humidity": humidity,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
    })

df.to_csv(r'weather_data.csv', index = False)

# %%
weather_df = pd.read_csv('weather_data.csv')
weather_df.head()
# Out:
#         City  Cloudiness Country        Date    Lat     Lng  Humidity  \
# 0   Denpasar          75      ID  1583617408  -8.65  115.22        94
# 1  Busselton          43      AU  1583616840 -33.65  115.33        71
# 2    Mataura         100      NZ  1583616837 -46.19  168.86        98
# 3      Vardø          32      NO  1583617090  70.37   31.11        82
# 4  Namatanai          97      PG  1583617070  -3.67  152.43        76
#
#    Max Temp  Wind Speed
# 0     80.60        5.82
# 1     62.01        7.96
# 2     57.99        8.01
# 3     29.14        7.29
# 4     82.99        7.61

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
